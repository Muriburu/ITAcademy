# %% [markdown]
# Idea principal
#
# ### Estudiar la incidencia de trastornos mentales en Europa (o todo el mundo de forma general y especificar Europa o España)
# - Ansiedad, depresión, bipolaridad, esquizofrenia, trastonos alimenticios, alcoholismo, abuso de otras drogas
# - Evolución en el tiempo --> desde 1950 hasta 2021
# - Estduar diferencias por edad, género, nivel socioeconómico, región geográfica
# - Factores socioeconómicos principales: desempleo, nivel económico, acceso a atención médica
# - Factores ambientales: contaminación, densidad de población
# - Uso de fármacos antidepresivos, ansiolíticos, psicotrópicos, etc
# - Afectación tras pandemia --> 2020 y 2021 efecto pandemia. Podría encontrar datos más actuales??
# - Afectación crisis económica actual, guerras, etc

# %% [markdown]
# ### Contexto
# Avances tecnológicos, cuidado de la salud, alargamiento de la esperanza de vida... Aumento del ritmo de vida y su impacto en la salud mental.

# %% [markdown]
# ### Hipótesis o preguntas
# ¿Cómo está nuestra salud mental?
# ¿La estamos cuidando?
# ¿Qué factores la hacen más vulnerable?
#
# conector de power point para importar archivos html webviewer

# %%
"""1º Importo las librerías que creo que puedo necesitar en esta tarea."""

import mysql.connector
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
import squarify
import plotly.io as pio

# %%
doc1 = pd.read_csv(r"C:/Users/maria/ITAcademy/Sprint 10 - Pràctica final/IHME Global Burden of Disease - Mental Health/Opción 1/IHME-GBD_2021_DATA-71016e7b-1.csv")
doc2 = pd.read_csv(r"C:/Users/maria/ITAcademy/Sprint 10 - Pràctica final/IHME Global Burden of Disease - Mental Health/Opción 1/IHME-GBD_2021_DATA-71016e7b-2.csv")
option1 = pd.concat([doc1, doc2])
print(option1.info())
option1 = option1.drop(columns=['measure_id', 'measure_name', 'location_id', 'sex_id', 'age_id', 'metric_id', 'metric_name', 'upper', 'lower'])

option1 = option1[option1["sex_name"] != "Ambos"]

option1
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 793152 entries, 0 to 293151
# Data columns (total 14 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   measure_id     793152 non-null  int64
#  1   measure_name   793152 non-null  object
#  2   location_id    793152 non-null  int64
#  3   location_name  793152 non-null  object
#  4   sex_id         793152 non-null  int64
#  5   sex_name       793152 non-null  object
#  6   age_id         793152 non-null  int64
#  7   age_name       793152 non-null  object
#  8   metric_id      793152 non-null  int64
#  9   metric_name    793152 non-null  object
#  10  year           793152 non-null  int64
#  11  val            793152 non-null  float64
#  12  upper          793152 non-null  float64
#  13  lower          793152 non-null  float64
# dtypes: float64(3), int64(6), object(5)
# memory usage: 90.8+ MB
# None
#         location_name sex_name age_name  year          val
# ...

# %%
option1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 528768 entries, 0 to 293150
# Data columns (total 5 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   location_name  528768 non-null  object
#  1   sex_name       528768 non-null  object
#  2   age_name       528768 non-null  object
#  3   year           528768 non-null  int64
#  4   val            528768 non-null  float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 24.2+ MB

# %%
table = pd.pivot_table(data=option1, index=["location_name", "year", "age_name"], columns="sex_name", values="val")
table.reset_index(inplace=True)
table
# Out:
# sex_name location_name  year    age_name         Hombre          Mujer
# 0           Afganistán  1950  10-14 años  431925.684893  393476.725531
# 1           Afganistán  1950  15-19 años  391221.931939  351592.338607
# 2           Afganistán  1950  20-24 años  357010.934313  304168.796081
# 3           Afganistán  1950  25-29 años  312355.344479  263150.196554
# 4           Afganistán  1950  30-34 años  269835.485933  223567.521239
# ...                ...   ...         ...            ...            ...
# 264379        Zimbabue  2021  75-79 años   29976.680537   46409.780553
# 264380        Zimbabue  2021       80-84   13054.681946   20009.020006
# 264381        Zimbabue  2021       85-90    4407.492137    6762.893577
# 264382        Zimbabue  2021       90-94     970.278763    1669.721519
# 264383        Zimbabue  2021    95+ años     152.558049     356.708417
#
# [264384 rows x 5 columns]

# %%
table_spain = table.iloc(["location_name"] == "España")
table_spain
#table.groupby("age_name")[["Hombre", "Mujer"]].sum()

# %%
option1["year"].unique()
# Out:
# array([1950, 1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959, 1960,
#        1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971,
#        1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982,
#        1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993,
#        1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004,
#        2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015,
#        2016, 2017, 2018, 2019, 2020, 2021])

# %%
option1["location_name"].unique()
# Out:
# array(['Nueva Zelanda', 'Irán', 'Jordania', 'Níger', 'China', 'Taiwán',
#        'Andorra', 'Bélgica', 'Sudán', 'Líbano', 'Santo Tomé y Príncipe',
#        'Sierra Leona', 'Mauritania', 'Nigeria', 'Corea del Norte',
#        'Australia', 'Dinamarca', 'Francia', 'Marruecos', 'Iraq', 'Kuwait',
#        'Camboya', 'Laos', 'Austria', 'Chipre', 'Senegal', 'Togo',
#        'Indonesia', 'Malasia', 'Finlandia', 'Alemania', 'Libia',
#        'Palestina', 'Egipto', 'Omán', 'Arabia Saudita', 'Grecia',
#        'Irlanda', 'Catar', 'Siria', 'Islandia', 'Israel', 'Birmania',
#        'Sri Lanka', 'Maldivas', 'Samoa Americana', 'Bermudas', 'Turquía',
#        'Yemen', 'Groenlandia', 'Guam', 'Luxemburgo', 'Holanda',
#        'Timor Oriental', 'Mónaco', 'Nauru', 'Niue', 'Bangladés',
#        'Filipinas', 'Portugal', 'Suecia', 'Kiribati',
#        'Estados Federados de Micronesia', 'India', 'Pakistán', 'Túnez',
#        'Emiratos Árabes Unidos', 'Islas Cook', 'Italia', 'Tailandia',
# ...

# %%
doc1 = pd.read_csv(r"C:/Users/maria/ITAcademy/Sprint 10 - Pràctica final/IHME Global Burden of Disease - Mental Health/Opción 2/IHME-GBD_2021_DATA-594bea04-1.csv")
doc2 = pd.read_csv(r"C:/Users/maria/ITAcademy/Sprint 10 - Pràctica final/IHME Global Burden of Disease - Mental Health/Opción 2/IHME-GBD_2021_DATA-594bea04-2.csv")
doc3 = pd.read_csv(r"C:/Users/maria/ITAcademy/Sprint 10 - Pràctica final/IHME Global Burden of Disease - Mental Health/Opción 2/IHME-GBD_2021_DATA-594bea04-3.csv")
option2 = pd.concat([doc1, doc2, doc3])
print(option2.info())

option2
# C:\Users\maria\ITAcademy\Sprint 10 - Pràctica final\IHME Global Burden of Disease - Mental Health\Opción 2\IHME-GBD_2021_DATA-594bea04-1.csv
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1088640 entries, 0 to 88639
# Data columns (total 14 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   measure_id     1088640 non-null  int64
#  1   measure_name   1088640 non-null  object
#  2   location_id    1088640 non-null  int64
#  3   location_name  1088640 non-null  object
#  4   sex_id         1088640 non-null  int64
#  5   sex_name       1088640 non-null  object
#  6   age_id         1088640 non-null  int64
#  7   age_name       1088640 non-null  object
#  8   metric_id      1088640 non-null  int64
#  9   metric_name    1088640 non-null  object
#  10  year           1088640 non-null  int64
#  11  val            1088640 non-null  float64
#  12  upper          1088640 non-null  float64
#  13  lower          1088640 non-null  float64
# dtypes: float64(3), int64(6), object(5)
# memory usage: 124.6+ MB
# None
# ...

# %% [markdown]
# Archivo excel Mental Health_fl_530_volume_A
# "C:\Users\maria\ITAcademy\Sprint 10 - Pràctica final\European Mental Health\Mental Health_fl_530_volume_A.xlsx"

# %%
excelA = pd.read_excel("C:/Users/maria/ITAcademy/Sprint 10 - Pràctica final/European Mental Health/Mental Health_fl_530_volume_A.xlsx")
excelA.dropna()
# Out:
#    Unnamed: 0                                         Unnamed: 1
# 7          Q1  Q1 Which of the following statements best desc...
# 8          Q2  Q2 To what extent have the recent world events...
# 9          Q3  Q3 In your opinion, which of the following act...
# 10         Q4  Q4 In your opinion, which of the following fac...
# 11         Q5  Q5 In your opinion, in which areas can the Eur...
# 12         Q6  Q6 Where do you think mental health problems c...
# 13         Q7  Q7 When thinking about good quality mental hea...
# 14       Q8_1  Q8_1 How would you rate the quality of mental ...
# 15       Q8_2  Q8_2 How would you rate the quality of mental ...
# 16       Q8_3  Q8_3 How would you rate the quality of mental ...
# 17         Q9  Q9 Have you or any of your family members ever...
# 18        Q10  Q10 Which of the following issue(s) did you or...
# 19        Q11  Q11 Can the use of social media by children an...
# ...

# %%
excelAQ1 = pd.read_excel("C:/Users/maria/ITAcademy/Sprint 10 - Pràctica final/European Mental Health/Mental Health_fl_530_volume_A.xlsx", sheet_name="Q1")
excelAQ1
# Out:
#                                                  Home Unnamed: 1  \
# 0                             Flash Eurobarometer 530        NaN
# 1                                       Mental health        NaN
# 2                      Fieldwork: 14/6/2023-21/6/2023        NaN
# 3                                 VOLUME A (Weighted)        NaN
# 4                                                 NaN        NaN
# 5   Q1 Which of the following statements best desc...        NaN
# 6                                           Base: All        NaN
# 7                                                 NaN        NaN
# 8                                                 NaN        NaN
# 9                                                 NaN        NaN
# 10                                                NaN       EU27
# 11                                                NaN        NaN
# 12                                                NaN        NaN
# ...
